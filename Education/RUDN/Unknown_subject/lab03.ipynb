# %%
import requests
import json

# %%
url = 'https://oauth.vk.com/authorize?client_id=7866591&display=page&redirect_uri=https://oauth.vk.com/blank.html&scope=docs&response_type=token&v=5.5.89'

req_1 = requests.get(url)

# %%
print(req_1.text)
# Out:
#             <!DOCTYPE html>
#       <html lang="ru" class="vk vk_js_no vk_1x vk_flex_no r d h  vk_appAuth_no n vk_old  vk_schemes_no  ">
#       <head>
#               <meta charset="utf-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, minimal-ui, user-scalable=no" />
#         <meta name="format-detection" content="telephone=no" />
#         <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#         <meta name="MobileOptimized" content="176" />
#         <meta name="HandheldFriendly" content="True" />
#         <base id="base">
#
#         <meta name="description" content="" />
#         <meta property="og:description" content="" />
#         <link rel="shortcut icon" href="/images/icons/favicons/fav_logo.ico?8"></link>
#             <meta name="theme-color" content="#ffffff" />
#     <link rel="icon" type="image/png" sizes="32x32" href="/images/icons/pwa/favicon_32.png?11">
# ...

# %%
url_a = 'https://api.vk.com/method/friends.getOnline'
token = '66be76d43989560f8f766f1224cd7c583f1ba19384b182bdad0f03376e21c456dd074283310021d1c20b6'
payload_a = { 'v': '5.89', 'access_token': token }

r = requests.get(url_a, params=payload_a)

r.text
# Out:
# '{"response":[6960099,9364486,12633644,46932139,83543811,111451686,155705451,169012788,181340960,190522353,217421315,301061599,329991339,430886849,504407922,525270566]}'

# %%
url_info = 'https://vk.com/dev/users.get'
req = requests.get(url_info)

# %%
print(req.headers)
# Out:
# {'Server': 'kittenx', 'Date': 'Sun, 30 May 2021 15:04:07 GMT', 'Content-Type': 'text/html; charset=windows-1251', 'Content-Length': '33136', 'Connection': 'keep-alive', 'X-Powered-By': 'KPHP/7.4.107319', 'Set-Cookie': 'remixir=DELETED; expires=Thu, 01 Jan 1970 00:00:01 GMT; path=/; domain=.vk.com; secure; HttpOnly, remixlang=0; expires=Sun, 22 May 2022 20:14:32 GMT; path=/; domain=.vk.com, remixstid=31173722_ceNdsthCxlb1z7ZtRbazUrWgj2KQqqpYnB3i9qF4Qvo; expires=Mon, 23 May 2022 00:42:14 GMT; path=/; domain=.vk.com; secure, remixlhk=6de6707a0cbc22c4e9; expires=Sun, 05 Jun 2022 12:42:11 GMT; path=/; domain=.vk.com; secure', 'Cache-control': 'no-store', 'Content-Security-Policy': "default-src * data: blob: about: vkcalls:;script-src 'self' https://vk.com https://*.vk.com https://static.vk.me https://*.mail.ru https://r.mradx.net https://s.ytimg.com https://platform.twitter.com https://cdn.syndication.twimg.com https://www.instagram.com https://connect.facebook.net https://telegram.org ht
# ...

# %%
requests.get('https://api.vk.com')
# Out:
# <Response [403]>

# %%
url_s = 'https://api.vk.com/method/users.search'
payload_s = {'q': 'Артём Ерёменко', 'v': '5.89', 'access_token': token, 'count': 5, 'city': 2, 'fields': 'city' }

r_s = requests.post(url_s, params=payload_s)

json.loads(r_s.text)
# Out:
# {'response': {'count': 33,
#   'items': [{'first_name': 'Ерёменко',
#     'id': 618184101,
#     'last_name': 'Артем',
#     'can_access_closed': True,
#     'is_closed': False,
#     'city': {'id': 2, 'title': 'Санкт-Петербург'},
#     'track_code': 'c93998a3KBB3F3kSlIDtnwWCPWyQKWwb99pjVZUlrF2AZkFcMxxPeT0SICPEiLCZPVebvU8uBBXx2WNVm0M'},
#    {'first_name': 'Artem',
#     'id': 342862865,
#     'last_name': 'Eremenko',
#     'can_access_closed': True,
#     'is_closed': False,
#     'track_code': 'b05a95dfAQ9qZK4C_2OsXLs3nmakAiTNJKToR-ALRwWjbJlbKERmZiE3_mr7ZKcAjOQxsX8FTMMip-hH7m0'},
#    {'first_name': 'Артем',
#     'id': 396128839,
#     'last_name': 'Ерёменко',
#     'can_access_closed': True,
#     'is_closed': False,
#     'city': {'id': 2, 'title': 'Санкт-Петербург'},
#     'track_code': '98856716vreTyxu5nXSVb03oSBOnbdzpV79nHnM2FwtvT9otqNzZ3tHLRYTMfMJufTHnwXBqtOdRvGcefVA'},
#    {'first_name': 'Артём',
#     'id': 464374176,
#     'last_name': 'Еременко',
# ...

# %%
url_co = 'https://api.vk.com/method/database.getCountries'
payload_co = {'code': 'RU', 'v': '5.89', 'access_token': token }

r_co = requests.get(url_co, params=payload_co)

json.loads(r_co.text)
# Out:
# {'response': {'count': 1, 'items': [{'id': 1, 'title': 'Россия'}]}}

# %%
url_co = 'https://api.vk.com/method/database.getCities'
payload_co = {'country_id': 1, 'q': 'Краснодар', 'v': '5.89', 'access_token': token }

r_co = requests.get(url_co, params=payload_co)

json.loads(r_co.text)
# Out:
# {'response': {'count': 10,
#   'items': [{'id': 72,
#     'title': 'Краснодар',
#     'area': 'Городской округ Краснодар район',
#     'region': 'Краснодарский край'},
#    {'id': 1023973,
#     'title': 'Краснодар',
#     'area': 'Богучарский район',
#     'region': 'Воронежская область'},
#    {'id': 1041247,
#     'title': 'Краснодарский',
#     'area': 'Красноармейский район',
#     'region': 'Краснодарский край'},
#    {'id': 1041308,
#     'title': 'Краснодарский',
#     'area': 'Городской округ Краснодар район',
#     'region': 'Краснодарский край'},
#    {'id': 1091932,
#     'title': 'Краснодарский',
#     'area': 'Новоалександровский район',
#     'region': 'Ставропольский край'},
#    {'id': 1500206,
#     'title': 'Краснодарка',
#     'area': 'Красногвардейский район',
#     'region': 'Крым'},
#    {'id': 1041306,
#     'title': 'Учебное Хозяйство Краснодарское',
#     'area': 'Краснодар город',
#     'region': 'Городской округ Краснодар район'},
#    {'id': 1078815,
# ...

# %%
url_sc = 'https://api.vk.com/method/database.getSchools'
payload_sc = {'q': 'Гимназия №23', 'city_id': 72, 'v': '5.89', 'access_token': token }

r_sc = requests.get(url_sc, params=payload_sc)

json.loads(r_sc.text)
# Out:
# {'response': {'count': 1, 'items': [{'id': 553, 'title': 'Гимназия № 23'}]}}

# %%
url_un = 'https://api.vk.com/method/database.getUniversities'
payload_un = {'q': 'РУДН', 'city_id': 1, 'country_id': 1, 'v': '5.89', 'access_token': token }

r_un = requests.get(url_un, params=payload_un)

json.loads(r_un.text)
# Out:
# {'response': {'count': 1, 'items': [{'id': 338, 'title': 'РУДН'}]}}

# %%
audio_token = '6fb51a870db88b4f025406b55257f1c53ce6f7cc8205c3a374dedade02eb151a62667fade01d9954770e4'

url_audio = 'https://api.vk.com/method/audio.get'
payload_audio = {'v': '5.89', 'access_token': audio_token }

r_audio = requests.get(url_audio, params=payload_audio)

json.loads(r_audio.text)
# Out:
# {'response': {'count': 1,
#   'items': [{'id': 1,
#     'owner_id': 100,
#     'artist': 'и в официальных приложениях ВКонтакте',
#     'title': 'Аудио доступно на vk.com',
#     'duration': 25,
#     'date': 1481906888,
#     'url': 'https://vk.com/mp3/audio_api_unavailable.mp3'}]}}

# %%
docs_token = '5a85e13a732576bc93504b02c7f7d57fd557ce971930d7a9b06d058ffe52adf3ba90c4b79ebf147935a10'
url_docs = 'https://api.vk.com/method/docs.get'
payload_docs = {'count': 5, 'type': 1, 'v': '5.89', 'access_token': docs_token }

r_docs = requests.get(url_docs, params=payload_docs)

json.loads(r_docs.text)
# Out:
# {'response': {'count': 120,
#   'items': [{'id': 601122062,
#     'owner_id': 77231871,
#     'title': 'Chep_Kolom_Polyak_VisualGraph.pdf',
#     'size': 4879808,
#     'ext': 'pdf',
#     'date': 1621858006,
#     'type': 1,
#     'url': 'https://vk.com/doc77231871_601122062?hash=8984c42cc7bdae8fd1&dl=G43TEMZRHA3TC:1622392343:68106bfdddc26df640&api=1&no_preview=1'},
#    {'id': 601122060,
#     'owner_id': 77231871,
#     'title': 'Chepovskiy_Metod_CL.pdf',
#     'size': 4225678,
#     'ext': 'pdf',
#     'date': 1621858006,
#     'type': 1,
#     'url': 'https://vk.com/doc77231871_601122060?hash=2e8978b7d3c2d947d0&dl=G43TEMZRHA3TC:1622392343:4d63e4702e2c308d68&api=1&no_preview=1'},
#    {'id': 601122057,
#     'owner_id': 77231871,
#     'title': 'VisuaLyzer_Задание.docx',
#     'size': 13465,
#     'ext': 'docx',
#     'date': 1621858005,
#     'type': 1,
# ...

# %%
photos_token = 'b5433c3a60629c6f8ff47ce6e71434fa32fc5e53f4e5e5f41214c1870702d575babf53db0c40064eb2183'

url_photos = 'https://api.vk.com/method/photos.getAllComments'
payload_photos = {'owner_id': -1, 'v': '5.89', 'access_token': photos_token }

r_photos = requests.get(url_photos, params=payload_photos)

json.loads(r_photos.text)
# Out:
# {'response': {'count': 39,
#   'items': [{'id': 3017,
#     'from_id': 642654457,
#     'date': 1616404762,
#     'text': '我申请了四个域，然后授权就出现错误了。',
#     'pid': 456239099},
#    {'id': 3016,
#     'from_id': 642654457,
#     'date': 1616404724,
#     'text': '我可以在VK应用程序中添加几个基本域？',
#     'pid': 456239099},
#    {'id': 3015,
#     'from_id': 642654457,
#     'date': 1616404705,
#     'text': '',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -8,
#        'date': 1616404705,
#        'id': 457242259,
#        'owner_id': -1,
#        'has_tags': False,
#        'access_key': '9868618307717a35d8',
#        'sizes': [{'height': 44,
#          'url': 'https://sun2-10.userapi.com/impg/9pXUyqXVHjkh48JNtdQm5Ni28_H2F-JBrupIfg/uLvvMQDANPo.jpg?size=130x44&quality=96&sign=40577f08d05e7fb55138d21f62baf6d6&c_uniq_tag=1W1UC8wpUaHdpU1Ho4j50Q3Br-KMhcdmrlha3dp3jTM&type=album',
#          'type': 'm',
#          'width': 130},
#         {'height': 87,
# ...
