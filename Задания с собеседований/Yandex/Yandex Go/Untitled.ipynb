# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import datetime

# %%
df = pd.read_excel('6118149_OGR3NI9A.xlsx', sheet_name=1)

# %%
df[df['free_Кол-во водителей'] == df['free_Кол-во водителей'].max()]
# Out:
#                        Дата  free_Кол-во водителей  free_Время (сек)  \
# 115 2017-08-16 19:00:07.420                   1638           1156849
#
#      order_driving_Кол-во водителей  order_driving_Время (сек)  \
# 115                            1252                     680480
#
#      order_waiting_Кол-во водителей  order_waiting_Время (сек)  \
# 115                            1211                     377618
#
#      order_transporting_Кол-во водителей  order_transporting_Время (сек)  \
# 115                                 1362                         1952367
#
#      offline_Кол-во водителей  offline_Время (сек)  Всего_Кол-во водителей  \
# 115                      2647              3392100                    2769
#
#      Всего_Время (сек)
# 115            7559414

# %%
df[df['free_Кол-во водителей'] == df['free_Кол-во водителей'].min()]
# Out:
#                       Дата  free_Кол-во водителей  free_Время (сек)  \
# 52 2017-08-14 03:59:59.740                    143            109765
#
#     order_driving_Кол-во водителей  order_driving_Время (сек)  \
# 52                              94                      57831
#
#     order_waiting_Кол-во водителей  order_waiting_Время (сек)  \
# 52                              89                      26907
#
#     order_transporting_Кол-во водителей  order_transporting_Время (сек)  \
# 52                                   98                          151050
#
#     offline_Кол-во водителей  offline_Время (сек)  Всего_Кол-во водителей  \
# 52                       627              1407622                     641
#
#     Всего_Время (сек)
# 52            1753175

# %%
df['oder_total'] = df['order_driving_Время (сек)'] + df['order_waiting_Время (сек)'] + df['order_transporting_Время (сек)']
df['oder_total']
df['offline_free_total'] = df['free_Время (сек)'] + df['offline_Время (сек)']
df['offline_free_total']

df['соотношение'] = df['oder_total']/df['offline_free_total']
df['соотношение']

df[(df['Дата'] >= '2017-08-16 00:00:00.000') & (df['Дата'] < '2017-08-17 00:00:00.000')].head()
# Out:
#                        Дата  free_Кол-во водителей  free_Время (сек)  \
# 97  2017-08-16 00:59:59.515                    412            420617
# 98  2017-08-16 01:59:59.510                    279            325821
# 99  2017-08-16 02:59:59.505                    240            364276
# 100 2017-08-16 04:00:00.000                    203            262664
# 101 2017-08-16 05:00:00.490                    277            329550
#
#      order_driving_Кол-во водителей  order_driving_Время (сек)  \
# 97                              252                     128812
# 98                              173                      89864
# 99                              123                      58697
# 100                             108                      59198
# 101                             153                      72439
#
#      order_waiting_Кол-во водителей  order_waiting_Время (сек)  \
# 97                              241                      86747
# ...

# %%
df[df['free_Кол-во водителей'] == df['free_Кол-во водителей'].max()]
# Out:
#                        Дата  free_Кол-во водителей  free_Время (сек)  \
# 115 2017-08-16 19:00:07.420                   1638           1156849
#
#      order_driving_Кол-во водителей  order_driving_Время (сек)  \
# 115                            1252                     680480
#
#      order_waiting_Кол-во водителей  order_waiting_Время (сек)  \
# 115                            1211                     377618
#
#      order_transporting_Кол-во водителей  order_transporting_Время (сек)  \
# 115                                 1362                         1952367
#
#      offline_Кол-во водителей  offline_Время (сек)  Всего_Кол-во водителей  \
# 115                      2647              3392100                    2769
#
#      Всего_Время (сек)  oder_total  offline_free_total  соотношение
# 115            7559414     3010465             4548949     0.661794

# %%
df['oder_avrg'] = df['order_waiting_Время (сек)']/df['order_waiting_Кол-во водителей']
df[df['oder_avrg'] == df['oder_avrg'].max()]
# Out:
#                        Дата  free_Кол-во водителей  free_Время (сек)  \
# 145 2017-08-18 01:00:22.270                    803            568082
#
#      order_driving_Кол-во водителей  order_driving_Время (сек)  \
# 145                             606                     317087
#
#      order_waiting_Кол-во водителей  order_waiting_Время (сек)  \
# 145                             588                     280699
#
#      order_transporting_Кол-во водителей  order_transporting_Время (сек)  \
# 145                                  658                          845641
#
#      offline_Кол-во водителей  offline_Время (сек)  Всего_Кол-во водителей  \
# 145                      1512              2399981                    1552
#
#      Всего_Время (сек)  oder_total  offline_free_total  соотношение  \
# 145            4411490     1443427             2968063      0.48632
#
#       oder_avrg
# 145  477.379252

# %%
df[(df['Дата'] >= '02:00:00.000') & (df['Дата'] < '05:00:00.000')].head()
# Out:
# Empty DataFrame
# Columns: [Дата, free_Кол-во водителей, free_Время (сек), order_driving_Кол-во водителей, order_driving_Время (сек), order_waiting_Кол-во водителей, order_waiting_Время (сек), order_transporting_Кол-во водителей, order_transporting_Время (сек), offline_Кол-во водителей, offline_Время (сек), Всего_Кол-во водителей, Всего_Время (сек), oder_total, offline_free_total, соотношение, oder_avrg]
# Index: []

# %%
df['transport_to_total'] = df['order_transporting_Время (сек)']/df['Всего_Время (сек)']
df[df['transport_to_total'] == df['transport_to_total'].max()]
# Out:
#                       Дата  free_Кол-во водителей  free_Время (сек)  \
# 56 2017-08-14 07:59:59.720                   1109            426158
#
#     order_driving_Кол-во водителей  order_driving_Время (сек)  \
# 56                             968                     585722
#
#     order_waiting_Кол-во водителей  order_waiting_Время (сек)  \
# 56                             933                     309881
#
#     order_transporting_Кол-во водителей  order_transporting_Время (сек)  \
# 56                                  984                         1687474
#
#     offline_Кол-во водителей  offline_Время (сек)  Всего_Кол-во водителей  \
# 56                      1905              2192421                    2057
#
#     Всего_Время (сек)  oder_total  offline_free_total  соотношение  \
# 56            5201656     2583077             2618579     0.986442
#
#      oder_avrg  transport_to_total
# 56  332.133976            0.324411

# %%
df[(df['Дата'] >= '2017-08-13 10:00:00.000') & (df['Дата'] < '2017-08-13 13:00:00.000')]['order_transporting_Время (сек)'].sum()
# Out:
# 4503279

# %%
df[(df['Дата'] >= '2017-08-17 09:00:00.000') & (df['Дата'] < '2017-08-17 12:00:00.000')]['order_transporting_Время (сек)'].sum()
# Out:
# 3592544

# %%
df[(df['Дата'] >= '2017-08-16 17:00:00.000') & (df['Дата'] < '2017-08-16 20:00:00.000')]['order_transporting_Время (сек)'].sum()
# Out:
# 6345978

# %%
df[(df['Дата'] >= '2017-08-13 18:00:00.000') & (df['Дата'] < '2017-08-13 21:00:00.000')]['order_transporting_Время (сек)'].sum()
# Out:
# 4180819
